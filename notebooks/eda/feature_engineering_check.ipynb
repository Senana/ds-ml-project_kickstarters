# %%
#default imports 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import os
#settings 
pd.set_option("display.max_columns", None)

# %%
dfc = pd.read_csv('../../data/cleaned/kickstarter_cleaned_with_cancelled.csv')
dfp = pd.read_csv('../../data/cleaned/kickstarter_cleaned.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dfc = pd.read_csv('../../data/cleaned/kickstarter_cleaned_with_cancelled.csv')
#       2 dfp = pd.read_csv('../../data/cleaned/kickstarter_cleaned.csv')
#
# ...
